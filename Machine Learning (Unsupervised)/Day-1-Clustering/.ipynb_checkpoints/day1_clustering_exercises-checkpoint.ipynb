# %% [markdown]
# # Part 1: Clustering
#
# Perform clustering on FIFA 18 player performance data (PlayerAttributeData.csv)
#
# - Use both visuals and statistical methods (elbow) to identify a cluster multiplicity
# - Use the PlayerPersonalData.csv data to assign a label to each cluster (e.g. cluster x - average age is young, nationality is Spanish, and wages are high)

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd
import numpy as np
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans

# %%
df_attribute = pd.read_csv('fifa18players/PlayerAttributeData.csv')

# %%
df_personal = pd.read_csv('fifa18players/PlayerPersonalData.csv')

# %%
df_attribute
# Out:
#        Unnamed: 0 Acceleration Aggression Agility Balance Ball control  \
# 0               0           89         63      89      63           93
# 1               1           92         48      90      95           95
# 2               2           94         56      96      82           95
# 3               3           88         78      86      60           91
# 4               4           58         29      52      35           48
# ...           ...          ...        ...     ...     ...          ...
# 17976       17976           24         16      38      26           12
# 17977       17977           25         44      35      44           22
# 17978       17978           66         26      60      77           41
# 17979       17979           57         46      58      74           43
# 17980       17980           48         52      49      47           32
#
#       Composure Crossing Curve Dribbling  ... Reactions Short passing  \
# 0            95       85    81        91  ...        96            83
# 1            96       77    89        97  ...        95            88
# 2            92       75    81        96  ...        88            81
# 3            83       77    86        86  ...        93            83
# 4            70       15    14        30  ...        85            55
# ...         ...      ...   ...       ...  ...       ...           ...
# 17976        23       14    13        12  ...        40            19
# 17977        44       11    12        11  ...        51            12
# 17978        50       28    32        37  ...        54            42
# 17979        45       34    30        41  ...        49            49
# 17980        33       19    17        23  ...        40            31
#
#       Shot power Sliding tackle Sprint speed Stamina Standing tackle Strength  \
# 0             94             23           91      92              31       80
# 1             85             26           87      73              28       59
# 2             80             33           90      78              24       53
# 3             87             38           77      89              45       80
# 4             25             11           61      44              10       83
# ...          ...            ...          ...     ...             ...      ...
# 17976         19             10           32      28              11       50
# 17977         13             13           25      32              12       47
# 17978         42             14           51      33              17       32
# 17979         43             47           58      49              48       46
# 17980         21             43           49      55              44       67
#
#        Vision Volleys
# 0          85      88
# 1          90      85
# 2          80      83
# 3          84      88
# 4          70      11
# ...       ...     ...
# 17976      26       6
# 17977      17      12
# 17978      37      33
# 17979      51      25
# 17980      22      19
#
# [17981 rows x 36 columns]

# %%
len(df_attribute['ID'].unique())
# Out:
# 17929

# %%
df_attribute = df_attribute.drop(columns=['Unnamed: 0'])

# %%
df_attribute.drop_duplicates(keep='first')
# Out:
#       Acceleration Aggression Agility Balance Ball control Composure Crossing  \
# 0               89         63      89      63           93        95       85
# 1               92         48      90      95           95        96       77
# 2               94         56      96      82           95        92       75
# 3               88         78      86      60           91        83       77
# 4               58         29      52      35           48        70       15
# ...            ...        ...     ...     ...          ...       ...      ...
# 17976           24         16      38      26           12        23       14
# 17977           25         44      35      44           22        44       11
# 17978           66         26      60      77           41        50       28
# 17979           57         46      58      74           43        45       34
# 17980           48         52      49      47           32        33       19
#
#       Curve Dribbling Finishing  ... Reactions Short passing Shot power  \
# 0        81        91        94  ...        96            83         94
# 1        89        97        95  ...        95            88         85
# 2        81        96        89  ...        88            81         80
# 3        86        86        94  ...        93            83         87
# 4        14        30        13  ...        85            55         25
# ...     ...       ...       ...  ...       ...           ...        ...
# 17976    13        12         5  ...        40            19         19
# 17977    12        11        11  ...        51            12         13
# 17978    32        37        47  ...        54            42         42
# 17979    30        41        32  ...        49            49         43
# 17980    17        23        20  ...        40            31         21
#
#       Sliding tackle Sprint speed Stamina Standing tackle  Strength Vision  \
# 0                 23           91      92              31        80     85
# 1                 26           87      73              28        59     90
# 2                 33           90      78              24        53     80
# 3                 38           77      89              45        80     84
# 4                 11           61      44              10        83     70
# ...              ...          ...     ...             ...       ...    ...
# 17976             10           32      28              11        50     26
# 17977             13           25      32              12        47     17
# 17978             14           51      33              17        32     37
# 17979             47           58      49              48        46     51
# 17980             43           49      55              44        67     22
#
#       Volleys
# 0          88
# 1          85
# 2          83
# 3          88
# 4          11
# ...       ...
# 17976       6
# 17977      12
# 17978      33
# 17979      25
# 17980      19
#
# [17929 rows x 35 columns]

# %%
df_attribute = df_attribute.drop(columns=['ID'])

# %% [markdown]
# Check if any of the values in data are missing

# %%
df_attribute.isnull().values.any()
# Out:
# False

# %% [markdown]
# Check data types, if not numeric, we will convert to numeric to allow data manipulation

# %%
df_attribute.dtypes
# Out:
# Acceleration          object
# Aggression            object
# Agility               object
# Balance               object
# Ball control          object
# Composure             object
# Crossing              object
# Curve                 object
# Dribbling             object
# Finishing             object
# Free kick accuracy    object
# GK diving             object
# GK handling           object
# GK kicking            object
# GK positioning        object
# GK reflexes           object
# Heading accuracy      object
# Interceptions         object
# Jumping               object
# Long passing          object
# Long shots            object
# Marking               object
# Penalties             object
# Positioning           object
# Reactions             object
# Short passing         object
# Shot power            object
# Sliding tackle        object
# Sprint speed          object
# Stamina               object
# Standing tackle       object
# Strength              object
# Vision                object
# Volleys               object
# dtype: object

# %%
df_attribute = df_attribute.astype(str)

# %%
df_attribute = df_attribute.applymap(eval)

# %%
df_attribute.dtypes
# Out:
# Acceleration          int64
# Aggression            int64
# Agility               int64
# Balance               int64
# Ball control          int64
# Composure             int64
# Crossing              int64
# Curve                 int64
# Dribbling             int64
# Finishing             int64
# Free kick accuracy    int64
# GK diving             int64
# GK handling           int64
# GK kicking            int64
# GK positioning        int64
# GK reflexes           int64
# Heading accuracy      int64
# Interceptions         int64
# Jumping               int64
# Long passing          int64
# Long shots            int64
# Marking               int64
# Penalties             int64
# Positioning           int64
# Reactions             int64
# Short passing         int64
# Shot power            int64
# Sliding tackle        int64
# Sprint speed          int64
# Stamina               int64
# Standing tackle       int64
# Strength              int64
# Vision                int64
# Volleys               int64
# dtype: object

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(df_attribute)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(df_attribute)
centroids = kmeans.cluster_centers_

# %%
labels
# Out:
# array([4, 4, 4, ..., 0, 1, 1], dtype=int32)

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from yellowbrick.cluster import KElbowVisualizer

# %%
# Instantiate the clustering model and visualizer
model = KMeans(
    n_clusters=12,
    init='k-means++',
    n_init=10,
    max_iter=200,
    tol=0.0001,
    precompute_distances='auto',
    verbose=2,
    random_state=None,
    copy_x=True,
    n_jobs=-1,
    algorithm='auto',
)
visualizer = KElbowVisualizer(model, k=(1,14))

visualizer.fit(df_attribute)        # Fit the data to the visualizer
visualizer.show()                   # Finalize and render the figure
;
# Out:
# ''

# %% [markdown]
# We can see that our elbow is identified at k=4

# %%
modfit = KMeans(n_clusters=4).fit(df_attribute)

# %%
labels = modfit.predict(df_attribute)

# %%
labels
# Out:
# array([0, 0, 0, ..., 0, 2, 2], dtype=int32)

# %%
df_attribute['cluster_id'] = labels

# %%
df_attribute2 = df_attribute.sort_values(by='cluster_id')

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
sns.heatmap(df_attribute2)

# %% [markdown]
# From the heatmap that we produced after ordering by cluster id, we can clearly sep

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
sns.clustermap(df_attribute)

# %%
df_attribute_new = pd.read_csv('fifa18players/PlayerAttributeData.csv')
# Out:
# /Users/timothypillow/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (11,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_attribute.drop_duplicates(keep='first')
df_attribute_new = df_attribute_new.astype(str)
df_attribute_new = df_attribute_new.applymap(eval)
df_attribute_new = df_attribute_new.drop(columns=['Unnamed: 0'])

# %%
df_attribute_new['cluster_id'] = labels

# %%
df_joined = pd.concat([df_attribute_new['cluster_id'], df_personal], axis=1)

# %%
df_joined
# Out:
#        cluster_id               Name  Age  \
# 0               1  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               1             Neymar   25
# 3               3          L. Suárez   30
# 4               2           M. Neuer   31
# ...           ...                ...  ...
# 17976           2          A. Kelsey   17
# 17977           2      B. Richardson   47
# 17978           1           J. Young   17
# 17979           0       J. Lundstram   18
# 17980           0          L. Sackey   18
#
#                                                  Photo Nationality  \
# 0       https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1      https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2      https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3      https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4      https://cdn.sofifa.org/48/18/players/167495.png     Germany
# ...                                                ...         ...
# 17976  https://cdn.sofifa.org/48/18/players/237463.png     England
# 17977   https://cdn.sofifa.org/48/18/players/11728.png     England
# 17978  https://cdn.sofifa.org/48/18/players/231381.png    Scotland
# 17979  https://cdn.sofifa.org/48/18/players/238813.png     England
# 17980  https://cdn.sofifa.org/48/18/players/238308.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 0       https://cdn.sofifa.org/flags/38.png       94         94
# 1       https://cdn.sofifa.org/flags/52.png       93         93
# 2       https://cdn.sofifa.org/flags/54.png       92         94
# 3       https://cdn.sofifa.org/flags/60.png       92         92
# 4       https://cdn.sofifa.org/flags/21.png       92         92
# ...                                     ...      ...        ...
# 17976   https://cdn.sofifa.org/flags/14.png       46         63
# 17977   https://cdn.sofifa.org/flags/14.png       46         46
# 17978   https://cdn.sofifa.org/flags/42.png       46         61
# 17979   https://cdn.sofifa.org/flags/14.png       46         64
# 17980  https://cdn.sofifa.org/flags/117.png       46         64
#
#                       Club                                    Club Logo  \
# 0           Real Madrid CF   https://cdn.sofifa.org/24/18/teams/243.png
# 1             FC Barcelona   https://cdn.sofifa.org/24/18/teams/241.png
# 2      Paris Saint-Germain    https://cdn.sofifa.org/24/18/teams/73.png
# 3             FC Barcelona   https://cdn.sofifa.org/24/18/teams/241.png
# 4         FC Bayern Munich    https://cdn.sofifa.org/24/18/teams/21.png
# ...                    ...                                          ...
# 17976    Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png
# 17977    Wycombe Wanderers  https://cdn.sofifa.org/24/18/teams/1933.png
# 17978         Swindon Town  https://cdn.sofifa.org/24/18/teams/1934.png
# 17979      Crewe Alexandra   https://cdn.sofifa.org/24/18/teams/121.png
# 17980    Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png
#
#         Value   Wage  Special
# 0      €95.5M  €565K     2228
# 1       €105M  €565K     2154
# 2       €123M  €280K     2100
# 3        €97M  €510K     2291
# 4        €61M  €230K     1493
# ...       ...    ...      ...
# 17976    €50K    €1K      755
# 17977      €0    €1K      832
# 17978    €60K    €1K     1194
# 17979    €60K    €1K     1302
# 17980    €50K    €1K     1031
#
# [17981 rows x 13 columns]

# %%
df_joined.drop_duplicates(keep='first')
# Out:
#        cluster_id               Name  Age  \
# 0               1  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               1             Neymar   25
# 3               3          L. Suárez   30
# 4               2           M. Neuer   31
# ...           ...                ...  ...
# 17976           2          A. Kelsey   17
# 17977           2      B. Richardson   47
# 17978           1           J. Young   17
# 17979           0       J. Lundstram   18
# 17980           0          L. Sackey   18
#
#                                                  Photo Nationality  \
# 0       https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1      https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2      https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3      https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4      https://cdn.sofifa.org/48/18/players/167495.png     Germany
# ...                                                ...         ...
# 17976  https://cdn.sofifa.org/48/18/players/237463.png     England
# 17977   https://cdn.sofifa.org/48/18/players/11728.png     England
# 17978  https://cdn.sofifa.org/48/18/players/231381.png    Scotland
# 17979  https://cdn.sofifa.org/48/18/players/238813.png     England
# 17980  https://cdn.sofifa.org/48/18/players/238308.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 0       https://cdn.sofifa.org/flags/38.png       94         94
# 1       https://cdn.sofifa.org/flags/52.png       93         93
# 2       https://cdn.sofifa.org/flags/54.png       92         94
# 3       https://cdn.sofifa.org/flags/60.png       92         92
# 4       https://cdn.sofifa.org/flags/21.png       92         92
# ...                                     ...      ...        ...
# 17976   https://cdn.sofifa.org/flags/14.png       46         63
# 17977   https://cdn.sofifa.org/flags/14.png       46         46
# 17978   https://cdn.sofifa.org/flags/42.png       46         61
# 17979   https://cdn.sofifa.org/flags/14.png       46         64
# 17980  https://cdn.sofifa.org/flags/117.png       46         64
#
#                       Club                                    Club Logo  \
# 0           Real Madrid CF   https://cdn.sofifa.org/24/18/teams/243.png
# 1             FC Barcelona   https://cdn.sofifa.org/24/18/teams/241.png
# 2      Paris Saint-Germain    https://cdn.sofifa.org/24/18/teams/73.png
# 3             FC Barcelona   https://cdn.sofifa.org/24/18/teams/241.png
# 4         FC Bayern Munich    https://cdn.sofifa.org/24/18/teams/21.png
# ...                    ...                                          ...
# 17976    Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png
# 17977    Wycombe Wanderers  https://cdn.sofifa.org/24/18/teams/1933.png
# 17978         Swindon Town  https://cdn.sofifa.org/24/18/teams/1934.png
# 17979      Crewe Alexandra   https://cdn.sofifa.org/24/18/teams/121.png
# 17980    Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png
#
#         Value   Wage  Special
# 0      €95.5M  €565K     2228
# 1       €105M  €565K     2154
# 2       €123M  €280K     2100
# 3        €97M  €510K     2291
# 4        €61M  €230K     1493
# ...       ...    ...      ...
# 17976    €50K    €1K      755
# 17977      €0    €1K      832
# 17978    €60K    €1K     1194
# 17979    €60K    €1K     1302
# 17980    €50K    €1K     1031
#
# [17929 rows x 13 columns]

# %%
df_joined.dtypes
# Out:
# cluster_id      int32
# Name           object
# Age             int64
# Photo          object
# Nationality    object
# Flag           object
# Overall         int64
# Potential       int64
# Club           object
# Club Logo      object
# Value          object
# Wage           object
# Special         int64
# dtype: object

# %%
df_joined['Wage'] = df_joined['Wage'].map(lambda x: x.lstrip('€K').rstrip('€K'))
df_joined['Value'] = df_joined['Value'].map(lambda x: x.lstrip('€KM').rstrip('€KM'))

# %%
df_joined = df_joined.sort_values(by='cluster_id')

# %%
df_joined
# Out:
#        cluster_id          Name  Age  \
# 17980           0     L. Sackey   18
# 12728           0       W. Hume   23
# 12730           0    F. Dimarco   19
# 12732           0   K. Mukuhara   27
# 4725            0      L. Antei   25
# ...           ...           ...  ...
# 5105            3   Vítor Silva   33
# 12285           3     D. Chávez   22
# 12284           3  P. Candelias   25
# 12308           3      O. Sveen   27
# 4423            3     H. Yamada   28
#
#                                                  Photo    Nationality  \
# 17980  https://cdn.sofifa.org/48/18/players/238308.png          Ghana
# 12728  https://cdn.sofifa.org/48/18/players/237275.png  United States
# 12730  https://cdn.sofifa.org/48/18/players/226268.png          Italy
# 12732  https://cdn.sofifa.org/48/18/players/237788.png          Japan
# 4725   https://cdn.sofifa.org/48/18/players/205529.png          Italy
# ...                                                ...            ...
# 5105    https://cdn.sofifa.org/48/18/players/13127.png       Portugal
# 12285  https://cdn.sofifa.org/48/18/players/226140.png         Mexico
# 12284  https://cdn.sofifa.org/48/18/players/160092.png          Chile
# 12308  https://cdn.sofifa.org/48/18/players/207459.png         Norway
# 4423   https://cdn.sofifa.org/48/18/players/224385.png          Japan
#
#                                        Flag  Overall  Potential  \
# 17980  https://cdn.sofifa.org/flags/117.png       46         64
# 12728   https://cdn.sofifa.org/flags/95.png       63         69
# 12730   https://cdn.sofifa.org/flags/27.png       63         77
# 12732  https://cdn.sofifa.org/flags/163.png       63         63
# 4725    https://cdn.sofifa.org/flags/27.png       71         74
# ...                                     ...      ...        ...
# 5105    https://cdn.sofifa.org/flags/38.png       70         70
# 12285   https://cdn.sofifa.org/flags/83.png       63         68
# 12284   https://cdn.sofifa.org/flags/55.png       63         63
# 12308   https://cdn.sofifa.org/flags/36.png       63         64
# 4423   https://cdn.sofifa.org/flags/163.png       71         71
#
#                               Club  \
# 17980            Scunthorpe United
# 12728                    FC Dallas
# 12730                      FC Sion
# 12732          Sanfrecce Hiroshima
# 4725              Benevento Calcio
# ...                            ...
# 5105              CF Reus Deportiu
# 12285  Tiburones Rojos de Veracruz
# 12284           Santiago Wanderers
# 12308                      Sogndal
# 4423                  Júbilo Iwata
#
#                                            Club Logo Value Wage  Special
# 17980    https://cdn.sofifa.org/24/18/teams/1949.png    50    1     1031
# 12728     https://cdn.sofifa.org/24/18/teams/695.png   425    1     1353
# 12730  https://cdn.sofifa.org/24/18/teams/110770.png   700    2     1612
# 12732  https://cdn.sofifa.org/24/18/teams/113157.png   300    1     1478
# 4725   https://cdn.sofifa.org/24/18/teams/112026.png   2.5   28     1478
# ...                                              ...   ...  ...      ...
# 5105   https://cdn.sofifa.org/24/18/teams/110854.png     1    6     1756
# 12285  https://cdn.sofifa.org/24/18/teams/110145.png   425    1     1702
# 12284  https://cdn.sofifa.org/24/18/teams/110976.png   400    1     1708
# 12308    https://cdn.sofifa.org/24/18/teams/1465.png   425    1     1711
# 4423   https://cdn.sofifa.org/24/18/teams/101144.png   2.4    6     1884
#
# [17981 rows x 13 columns]

# %%
df_joined.hist(figsize = (30,20));

# %%
df_joined.plot(x='cluster_id', y='Wage')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-297-7721648dd5cb> in <module>
# ----> 1 df_joined.plot(x='cluster_id', y='Wage')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot
