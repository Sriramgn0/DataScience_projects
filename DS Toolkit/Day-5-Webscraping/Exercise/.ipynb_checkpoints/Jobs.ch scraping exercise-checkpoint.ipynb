# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook as tqdm # this is a fancy progress bar!
from time import sleep
import numpy as np
from datetime import datetime
import pandas as pd

# %% [markdown]
# # Individual Data Challenge: Scraping Jobs.ch
#
# (Weekend homework recap)
#
# As a job seeker, one has to search through job portals to find most relevant jobs related to your profile.
#
# In this challenge, your goal is to find all jobs related to keywords: “Data Scientist”, “Data Analyst”, “Python Developer”, “Data Engineer”, “Data Manager”, “Data Architect”, “Big Data Analyst” and “Data Python” on jobs.ch.
#
# ## Questions
#
# Download all necessary information (including job text, job rank, company name, job keyword…) for all webpages.
# Using the information obtained, perform a descriptive analysis on this data including questions:
#
# 1. How many jobs are shared between these categories?
# 2. How much the keywords: “Data Analyst” and “Big Data Analyst” overlap?
# 3. Are there some companies doing more hires than average?
# 4. How many jobs are there in different Kantons?
# 5. Is “machine learning” keyword most often in data scientist or data analyst jobs?
# 6. What is the distribution of most common keywords between and across categories?
# 7. Produce a report in the form of a clean notebook (or jupyter slides), with commented code and markdown cells for structuring and interpretations.

# %%
# Create the link (it is a better idea to constuct the especially link if you notice a specific pattern..)
link_first_part = 'https://www.jobs.ch'
link_mid_1_part = '/en/vacancies/?page='
link_mid_2_part = '&term='
link_mid_3_part = "Data%20Engineer"

# %%
link = link_first_part + link_mid_1_part + link_mid_2_part + link_mid_3_part

# %%
link
# Out:
# 'https://www.jobs.ch/en/vacancies/?page=&term=Data%20Engineer'

# %%
response = requests.get(link, timeout = 15)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
response.status_code
# Out:
# 200

# %%
soup.find('div', class_ = 'Box-sc-7ekkso-0 Position-b2pct5-0 Position__Relative-b2pct5-1 VacancySerpItem__ShadowBox-p4qu0m-0 hthPRS')
# Out:
# <div class="Box-sc-7ekkso-0 Position-b2pct5-0 Position__Relative-b2pct5-1 VacancySerpItem__ShadowBox-p4qu0m-0 hthPRS"><a class="x--job-link t--job-link SearchVacancyResultsComponent__StyledVacancySerpItem-n25jij-0 dQDQbr" href="/en/vacancies/detail/9328560/?source=vacancy_search_promo"><div class="Box-sc-7ekkso-0 Paper-sc-10r6qoa-0 VacancySerpItem__StyledSerpItem-p4qu0m-2 exQanO" data-cy="vacancy-serp-item-active"><div class="Box-sc-7ekkso-0 Flex-zfb5z9-0 fKIKYn"><div class="Box-sc-7ekkso-0 Flex-zfb5z9-0 FlexItem-sc-15bj19c-0 hRmJUa"><div class="Div-v2w9ke-0 Flex-sc-4aokm-0 CompanyLogoWrapper-sc-1n5gkoi-0 VacancySerpItem___StyledCompanyLogoWrapper-p4qu0m-4 dklvqW" display="flex" height="48px" width="48px"><div class="Box-sc-7ekkso-0 Flex-zfb5z9-0 FlexItem-sc-15bj19c-0 kdXYoj" height="100%" width="100%"><img alt="Leica Geosystems AG" class="Box-sc-7ekkso-0 Image-ywupxk-0 jcoTeH VacancySerpItem__StyledCompanyLogo-p4qu0m-3 hxQAnS" src="https://img.jobs.ch/www/img/toplogos/18006.png"/></div></div></div><div class="Box-sc-7ekkso-0 Flex-zfb5z9-0 FlexItem-sc-15bj19c-0 VacancySerpItem___StyledFlexItem-p4qu0m-5 kXhdFw"><div><span class="VacancySerpItem__RecommendedLabel-p4qu0m-1 fKtuur">Recommended</span></div><span class="Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 VacancySerpItem___StyledText-p4qu0m-6 lhZdpZ" color="defaultBase" font-family="Helvetica Neue, Helvetica, Arial, sans-serif" font-size="m" font-weight="bold" letter-spacing="0.2px">Machine Learning Engineer (f/m)</span><span class="Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 cpXfsD" color="grayBase" font-family="Helvetica Neue, Helvetica, Arial, sans-serif" font-size="s" font-weight="regular" letter-spacing="0.2px" width="100%"><strong>Leica Geosystems AG</strong></span><span class="Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 cpXfsD" color="grayBase" font-family="Helvetica Neue, Helvetica, Arial, sans-serif" font-size="s" font-weight="regular" letter-spacing="0.2px" width="100%">Heerbrugg</span></div><div class="Box-sc-7ekkso-0 Flex-zfb5z9-0 utQIx"><div class="Box-sc-7ekkso-0 Flex-zfb5z9-0 FlexItem-sc-15bj19c-0 cjFWje"><button aria-label="Save" class="Button-sc-1w510ja-0 IconButton__StyledButton-sc-7slzuy-0 kTEbqg" height="50px" title="Save" width="50px"><span class="Span-bhy2uh-0 Icon-xhyn7y-0 iNzOTm" display="inline-block" height="24px" width="24px"><svg aria-hidden="true" fill="currentColor" focusable="false" height="24px" viewbox="0 0 24 24" width="24px"><path d="M12 22.8c-.1 0-.2 0-.3-.1C11.2 22.4 0 14.2 0 7.8 0 3.5 3.1 1 6.2 1c2 0 4.5 1.2 5.8 4.5C13.3 2.2 15.8 1 17.8 1c3 0 6.2 2.5 6.2 6.8 0 6.3-11.2 14.5-11.7 14.9-.1.1-.2.1-.3.1zM6.2 2C3.6 2 1 4.2 1 7.8c0 5.3 9.2 12.5 11 13.9 1.8-1.3 11-8.6 11-13.9C23 4.2 20.4 2 17.8 2c-2.5 0-4.5 2-5.3 5.2-.1.4-.9.4-1 0C10.7 4 8.7 2 6.2 2z"></path></svg></span></button></div><span class="Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 dIyNzY" color="grayLighten1" font-family="Helvetica Neue, Helvetica, Arial, sans-serif" font-size="xs" font-weight="regular" letter-spacing="0.2px"><span>09.11</span></span></div></div></div></a></div>

# %%
job_links = []
def get_links(soup, job_links):
    all_links = soup.find_all('div', class_ = 'Box-sc-7ekkso-0 Position-b2pct5-0 Position__Relative-b2pct5-1 VacancySerpItem__ShadowBox-p4qu0m-0 hthPRS')
    for job_add in all_links:
        job_links.append(link_first_part+job_add.find('a', {'class':'x--job-link t--job-link SearchVacancyResultsComponent__StyledVacancySerpItem-n25jij-0 dQDQbr'}).get('href'))

# %%
max_pages = soup.find('div', class_ = 'Div-v2w9ke-0 Flex-sc-4aokm-0 eykbax').text.split()[2]

# %%
for page in tqdm(range(1, int(max_pages)+1)[:]):
    url = link_first_part +link_mid_1_part + str(page) + link_mid_2_part + link_mid_3_part
    response = requests.get(url, timeout = 15)
    soup = BeautifulSoup(response.content, 'html.parser')
    get_links(soup, job_links)
    sleep(0.6)
# Out:
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')
source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000712435865e2fe7e041cd6347c0bd5819222831/?jobposition=10-11&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/00002270885fcedefbc0a955e80873bef7ab9d60e0/?jobposition=10-12&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000712435d34f56c90391878e56b761211044c8ab/?jobposition=10-13&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000712435d9479d855b55f623679fb4854796eb20/?jobposition=10-14&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000574983c82d3171a1620dfc4b71c2f25b5d1a4c/?jobposition=10-15&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000710079bedec5ca9485eb64003c57a3dfd152ad/?jobposition=10-16&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000055952c63f928139b467bb823c132e2b7cb825/?jobposition=10-17&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000057378afd51d8b16765f7295fb0cbbad30c046/?jobposition=10-18&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/0000056469b5d01dac334459254cf227a09ea0b9eb/?jobposition=10-19&source=vacancy_search',
#  'https://www.jobs.ch/en/vacancies/detail/000069066416e5bc2c2b479e0002797e12f524e182/?jobposition=10-20&source=vacancy_search']

# %%
#select a random job link from above to test that it's working
job_link = 'https://www.jobs.ch/en/vacancies/detail/9309672/?jobposition=1-1&source=vacancy_search_promo'

# %%
response = requests.get(job_link, timeout = 15)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
def get_content(soup):
    try:
        content = soup.find('div', class_ = 'Div-v2w9ke-0 fjQgMg').get_text()
    except:
        content = np.nan
    try:    
        title = soup.find('div', {'class' : 'Div-v2w9ke-0 hPuVjT'}).find('h1').get('title')
    except:
        title = np.nan
    try:
        company = soup.find('div', class_ = 'Div-v2w9ke-0 cvwY').find('a').get('title')
    except:
        company = np.nan
    try:
        published = soup.find('span', class_ = 'Span-bhy2uh-0 Badge-ndaeev-0 krRxxu').get_text()
    except: 
        published = np.nan
    try:
        location = soup.find('span', class_ = 'Span-bhy2uh-0 Text__span-sc-1vcmz87-8 YbklG Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 gdfMMD').get_text()
    except: 
        location = np.nan
        
    return content, title, company, published, location

# %%
get_content(soup)
# Out:
# (nan,
#  'Projektingenieur/in operatives Anlagenmanagement.',
#  'Schweizerische Bundesbahnen SBB',
#  '30.09.2019',
#  '\xa0— Zürich/ Work Smart')

# %%
cols = ['date', 'company', 'title', 'published', 'content', 'location']
df = pd.DataFrame(columns = cols)
df
# Out:
# Empty DataFrame
# Columns: [date, company, title, published, content, location]
# Index: []

# %%
for job in tqdm(job_links[:]):
    response = requests.get(job, timeout = 15)
    soup = BeautifulSoup(response.content, 'html.parser')
    content, title, company, published, location = get_content(soup)
    
    df = df.append({
        'date': datetime.now(), 
        'company': company, 
        'title': title, 
        'published': published, 
        'content': content,
        'location': location
        
        
    }, ignore_index = True)
    sleep(0.6)

df
# Out:
# HBox(children=(IntProgress(value=0, max=1195), HTML(value='')))
#                            date                                   company  \
# 0    2019-11-16 16:08:25.869767                       Leica Geosystems AG
# 1    2019-11-16 16:08:27.078153                                 Banian AG
# 2    2019-11-16 16:08:28.597206                    Experis Schweiz Zürich
# 3    2019-11-16 16:08:30.133922                     The Stamford Group AG
# 4    2019-11-16 16:08:31.643662                               uniqFEED AG
# 5    2019-11-16 16:09:49.145202                       Leica Geosystems AG
# 6    2019-11-16 16:09:50.449539                                 Banian AG
# 1187  Performance Consultant (Experienced, Lead or S...  09.07.2019
# 1188                          IT Performance Consultant  27.12.2018
# 1189                          IT Performance Consultant  27.12.2018
# 1190  Performance Consultant (Experienced, Lead or S...  14.09.2018
# 1191  Manager - Financial Services Consulting Transf...  07.11.2019
# 1192                               Automationsingenieur  29.08.2019
# 1193  Associate Sales Representative - Bachelor/Mast...  01.10.2019
# 1194  Projektingenieur/in operatives Anlagenmanagement.  30.09.2019
# 1195                    SUPPLIER DEVELOPMENT ANALYST IV  08.10.2019
# 1196           Senior Account Executive - Manufacturing  05.06.2019
# 1197          CONSULTANT FÜR SYSTEMARCHITEKTUR GA / ICT  09.07.2019
# 1198         (Senior) Consultant Digital Transformation  24.01.2019
# 1199  Building the next electronic identity (E-ID) f...  18.09.2019
#
#                                                 content  \
# 0     Job descriptionInfoCompanyMachine Learning Eng...
# 1                            Job descriptionInfoCompany
# 2     Job descriptionInfoCompanySenior Data Engineer...
# 3     Job descriptionInfoCompanyDevOps EngineerJob D...
# 4     Job descriptionInfoCompanyuniqFEED, a Spin-off...
# 5     Job descriptionInfoCompanyMachine Learning Eng...
# 6                            Job descriptionInfoCompany
# 7     Job descriptionInfoCompanySenior Data Engineer...
# 8     Job descriptionInfoCompanyDevOps EngineerJob D...
# 9     Job descriptionInfoCompanyuniqFEED, a Spin-off...
# 10                           Job descriptionInfoCompany
# 11    Job descriptionInfoCompanyCloud Site Reliabili...
# 12    Job descriptionInfoCompanyProduct Data Enginee...
# 13    Job descriptionInfoCompanyData Engineer mit Fl...
# 14    Job descriptionInfoCompanyWerden Sie Teil eine...
# 15                           Job descriptionInfoCompany
# 16    Job descriptionInfoCompanyMöchtest Du Teil der...
# 17                           Job descriptionInfoCompany
# 18                           Job descriptionInfoCompany
# 19    Job descriptionInfoCompanyHomegate is the lead...
# 20    Job descriptionInfoCompanySchneider Electric i...
# 21    Job descriptionInfoCompanyDevOps / Cloud Engin...
# 22    Job descriptionInfoCompanySenior FIX/Connectiv...
# 23    Job descriptionInfoCompanyZürcher Hochschule f...
# 24    Job descriptionInfoCompany Selbständiges Entwi...
# 25                           Job descriptionInfoCompany
# 26                           Job descriptionInfoCompany
# 27    Job descriptionInfoCompany Ausarbeiten der unt...
# 28    Job descriptionInfoCompanyDie VZ Depotbank geh...
# 29    Job descriptionInfoCompanyBusiness Engineer mi...
# ...                                                 ...
# 1170  Job descriptionInfoHead of Platform Engineerin...
# 1171  Job descriptionInfoTechnical Studentships - Ap...
# 1172  Job descriptionInfoCompanyC# Software Develope...
# 1173  Job descriptionInfoProcess Operator in Cryogen...
# 1174  Job descriptionInfoProduct Owner/Business Anal...
# 1175  Job descriptionInfoCompanySenior Manager Custo...
# 1176  Job descriptionInfoCompanyResearch Scientist -...
# 1177  Job descriptionInfoCompanyTeam Lead Functional...
# 1178  Job descriptionInfoWeb Developer (Python/Javas...
# 1179  Job descriptionInfoCompanyEngineering Technici...
# 1180  Job descriptionInfoCompanyTitle Solution Speci...
# 1181  Job descriptionInfoPre-Sales ConsultantDu weis...
# 1182  Job descriptionInfoMaster-Absolvent (w/m/d) al...
# 1183  Job descriptionInfoCompanyR&D Intern Process D...
# 1184  Job descriptionInfoSenior Consultant / Manager...
# 1185  Job descriptionInfoCompanyDevice Technology Ma...
# 1186  Job descriptionInfoCompanySenior Software-Entw...
# 1187  Job descriptionInfoCompanyPerformance Consulta...
# 1188  Job descriptionInfoCompanyIT Performance Consu...
# 1189  Job descriptionInfoCompanyIT Performance Consu...
# 1190  Job descriptionInfoCompanyPerformance Consulta...
# 1191  Job descriptionInfoCompanyManager - Financial ...
# 1192  Job descriptionInfoAutomationsingenieur   Die ...
# 1193  Job descriptionInfoAssociate Sales Representat...
# 1194  Job descriptionInfoCompanyProjektingenieur/in ...
# 1195  Job descriptionInfoCompanySUPPLIER DEVELOPMENT...
# 1196  Job descriptionInfoSenior Account Executive - ...
# 1197  Job descriptionInfoCONSULTANT FÜR SYSTEMARCHIT...
# 1198  Job descriptionInfoCompany(Senior) Consultant ...
# 1199  Job descriptionInfoCompanyBuilding the next el...
#
#                        location
# 0                     Heerbrugg
# 1                Deutschschweiz
# 2                        Zürich
# 3                        Zürich
# 4                    Glattbrugg
# 5                   — Heerbrugg
# 6              — Deutschschweiz
# 7                      — Zürich
# 8                      — Zürich
# 9                  — Glattbrugg
# 10                     — Zürich
# 11                     — Zürich
# 12            — Rapperswil-Jona
# 13                 — Winterthur
# 14      — Arbeitsort St. Gallen
# 15                     — Zürich
# 16                        — Zug
# 17                — Konolfingen
# 18                   — Pratteln
# 19                     — Zürich
# 20                     — Zürich
# 21                      — Basel
# 22                     — Zürich
# 23                 — Winterthur
# 24       — Wangen bei Dübendorf
# 25         — St. Johann / Basel
# 26          — Aarau AG (Aargau)
# 27                   — Buchs AG
# 28                        — Zug
# 29                     — Zürich
# ...                         ...
# 1170                        NaN
# 1171                        NaN
# 1172                 — Lausanne
# 1173                        NaN
# 1174                        NaN
# 1175   — Neuhausen am Rheinfall
# 1176           — Zürich, Zürich
# 1177                  — Thalwil
# 1178                    — Olten
# 1179               — Glattbrugg
# 1180                 — CH-Lonay
# 1181                        NaN
# 1182                        NaN
# 1183                    — Stäfa
# 1184                        NaN
# 1185                    — Basel
# 1186                   — Zürich
# 1187           — Zurich, Zürich
# 1188                   — Zürich
# 1189                    — Basel
# 1190                — Basel, BS
# 1191                   — Zurich
# 1192                        NaN
# 1193                        NaN
# 1194       — Zürich/ Work Smart
# 1195                  — Chochin
# 1196                        NaN
# 1197                        NaN
# 1198                   — Zürich
# 1199                 — Lausanne
#
# [1200 rows x 6 columns]

# %%
df['location'] = df['location'].str.replace('—', '')
df
# Out:
#                         date                 company  \
# 0 2019-11-16 16:08:25.869767     Leica Geosystems AG
# 1 2019-11-16 16:08:27.078153               Banian AG
# 2 2019-11-16 16:08:28.597206  Experis Schweiz Zürich
# 3 2019-11-16 16:08:30.133922   The Stamford Group AG
# 4 2019-11-16 16:08:31.643662             uniqFEED AG
# 27             Enterprise Data Engineer 80-100% (m/w/d)  01.11.2019
# 28                         Data Engineer (w/m, 80-100%)  29.10.2019
# 29    Business Engineer mit dem Schwerpunkt Datenman...  08.11.2019
# ...                                                 ...         ...
# 1170    Head of Platform Engineering for iptiQ EMEA P&C  11.06.2019
# 1171           Technical Studentships - Applied Physics  04.11.2019
# 1172                              C# Software Developer  19.08.2019
# 1173  Process Operator in Cryogenics (TE-CRG-OP-2019...  24.10.2019
# 1174           Product Owner/Business Analyst - Banking  11.11.2019
# 1175  Senior Manager Customer Experience Management ...  25.06.2019
# 1176                 Research Scientist - Mixed Reality  17.07.2019
# 1177     Team Lead Functional Safety Program Management  15.05.2019
# 1178             Web Developer (Python/Javascript) 100%  04.11.2019
# 1179                             Engineering Technician  19.08.2019
# 1180  Title Solution Specialist - FWP (Future Workpl...  08.04.2019
# 1181                               Pre-Sales Consultant  06.11.2019
# 1182  Master-Absolvent (w/m/d) als IT Consultant - D...  15.08.2019
# 1183  R&D Intern Process Development Environmental S...  24.09.2019
# 1184  Senior Consultant / Manager (w/m/d) im Asset M...  20.11.2018
# 1185  Device Technology Manager, Insulin Drug Delive...  13.09.2019
# 1186                     Senior Software-Entwickler(in)  11.07.2019
# 1187  Performance Consultant (Experienced, Lead or S...  09.07.2019
# 1188                          IT Performance Consultant  27.12.2018
# 1189                          IT Performance Consultant  27.12.2018
# 1190  Performance Consultant (Experienced, Lead or S...  14.09.2018
# 1191  Manager - Financial Services Consulting Transf...  07.11.2019
# 1192                               Automationsingenieur  29.08.2019
# 1193  Associate Sales Representative - Bachelor/Mast...  01.10.2019
# 1194  Projektingenieur/in operatives Anlagenmanagement.  30.09.2019
# 1195                    SUPPLIER DEVELOPMENT ANALYST IV  08.10.2019
# 1196           Senior Account Executive - Manufacturing  05.06.2019
# 1197          CONSULTANT FÜR SYSTEMARCHITEKTUR GA / ICT  09.07.2019
# 1198         (Senior) Consultant Digital Transformation  24.01.2019
# 1199  Building the next electronic identity (E-ID) f...  18.09.2019
#
#                                                 content  \
# 0     Job descriptionInfoCompanyMachine Learning Eng...
# 1                            Job descriptionInfoCompany
# 2     Job descriptionInfoCompanySenior Data Engineer...
# 3     Job descriptionInfoCompanyDevOps EngineerJob D...
# 4     Job descriptionInfoCompanyuniqFEED, a Spin-off...
# 5     Job descriptionInfoCompanyMachine Learning Eng...
# 6                            Job descriptionInfoCompany
# 7     Job descriptionInfoCompanySenior Data Engineer...
# 8     Job descriptionInfoCompanyDevOps EngineerJob D...
# 9     Job descriptionInfoCompanyuniqFEED, a Spin-off...
# 10                           Job descriptionInfoCompany
# 11    Job descriptionInfoCompanyCloud Site Reliabili...
# 12    Job descriptionInfoCompanyProduct Data Enginee...
# 13    Job descriptionInfoCompanyData Engineer mit Fl...
# 14    Job descriptionInfoCompanyWerden Sie Teil eine...
# 15                           Job descriptionInfoCompany
# 16    Job descriptionInfoCompanyMöchtest Du Teil der...
# 17                           Job descriptionInfoCompany
# 18                           Job descriptionInfoCompany
# 19    Job descriptionInfoCompanyHomegate is the lead...
# 20    Job descriptionInfoCompanySchneider Electric i...
# 21    Job descriptionInfoCompanyDevOps / Cloud Engin...
# 22    Job descriptionInfoCompanySenior FIX/Connectiv...
# 23    Job descriptionInfoCompanyZürcher Hochschule f...
# 24    Job descriptionInfoCompany Selbständiges Entwi...
# 25                           Job descriptionInfoCompany
# 26                           Job descriptionInfoCompany
# 27    Job descriptionInfoCompany Ausarbeiten der unt...
# 28    Job descriptionInfoCompanyDie VZ Depotbank geh...
# 29    Job descriptionInfoCompanyBusiness Engineer mi...
# ...                                                 ...
# 1170  Job descriptionInfoHead of Platform Engineerin...
# 1171  Job descriptionInfoTechnical Studentships - Ap...
# 1172  Job descriptionInfoCompanyC# Software Develope...
# 1173  Job descriptionInfoProcess Operator in Cryogen...
# 1174  Job descriptionInfoProduct Owner/Business Anal...
# 1175  Job descriptionInfoCompanySenior Manager Custo...
# 1176  Job descriptionInfoCompanyResearch Scientist -...
# 1177  Job descriptionInfoCompanyTeam Lead Functional...
# 1178  Job descriptionInfoWeb Developer (Python/Javas...
# 1179  Job descriptionInfoCompanyEngineering Technici...
# 1180  Job descriptionInfoCompanyTitle Solution Speci...
# 1181  Job descriptionInfoPre-Sales ConsultantDu weis...
# 1182  Job descriptionInfoMaster-Absolvent (w/m/d) al...
# 1183  Job descriptionInfoCompanyR&D Intern Process D...
# 1184  Job descriptionInfoSenior Consultant / Manager...
# 1185  Job descriptionInfoCompanyDevice Technology Ma...
# 1186  Job descriptionInfoCompanySenior Software-Entw...
# 1187  Job descriptionInfoCompanyPerformance Consulta...
# 1188  Job descriptionInfoCompanyIT Performance Consu...
# 1189  Job descriptionInfoCompanyIT Performance Consu...
# 1190  Job descriptionInfoCompanyPerformance Consulta...
# 1191  Job descriptionInfoCompanyManager - Financial ...
# 1192  Job descriptionInfoAutomationsingenieur   Die ...
# 1193  Job descriptionInfoAssociate Sales Representat...
# 1194  Job descriptionInfoCompanyProjektingenieur/in ...
# 1195  Job descriptionInfoCompanySUPPLIER DEVELOPMENT...
# 1196  Job descriptionInfoSenior Account Executive - ...
# 1197  Job descriptionInfoCONSULTANT FÜR SYSTEMARCHIT...
# 1198  Job descriptionInfoCompany(Senior) Consultant ...
# 1199  Job descriptionInfoCompanyBuilding the next el...
#
#                       location
# 0                    Heerbrugg
# 1               Deutschschweiz
# 2                       Zürich
# 3                       Zürich
# 4                   Glattbrugg
# 5                    Heerbrugg
# 6               Deutschschweiz
# 7                       Zürich
# 8                       Zürich
# 9                   Glattbrugg
# 10                      Zürich
# 11                      Zürich
# 12             Rapperswil-Jona
# 13                  Winterthur
# 14       Arbeitsort St. Gallen
# 15                      Zürich
# 16                         Zug
# 17                 Konolfingen
# 18                    Pratteln
# 19                      Zürich
# 20                      Zürich
# 21                       Basel
# 22                      Zürich
# 23                  Winterthur
# 24        Wangen bei Dübendorf
# 25          St. Johann / Basel
# 26           Aarau AG (Aargau)
# 27                    Buchs AG
# 28                         Zug
# 29                      Zürich
# ...                        ...
# 1170                       NaN
# 1171                       NaN
# 1172                  Lausanne
# 1173                       NaN
# 1174                       NaN
# 1175    Neuhausen am Rheinfall
# 1176            Zürich, Zürich
# 1177                   Thalwil
# 1178                     Olten
# 1179                Glattbrugg
# 1180                  CH-Lonay
# 1181                       NaN
# 1182                       NaN
# 1183                     Stäfa
# 1184                       NaN
# 1185                     Basel
# 1186                    Zürich
# 1187            Zurich, Zürich
# 1188                    Zürich
# 1189                     Basel
# 1190                 Basel, BS
# 1191                    Zurich
# 1192                       NaN
# 1193                       NaN
# 1194        Zürich/ Work Smart
# 1195                   Chochin
# 1196                       NaN
# 1197                       NaN
# 1198                    Zürich
# 1199                  Lausanne
#
# [1200 rows x 6 columns]

# %% [markdown]
# ### DATA SCIENTIST

# %%
# Create the link (it is a better idea to constuct the especially link if you notice a specific pattern..)
link_first_part = 'https://www.jobs.ch'
link_mid_1_part = '/en/vacancies/?page='
link_mid_2_part = '&term='
link_mid_3_part = "Data%20Scientist"

# %%
link = link_first_part + link_mid_1_part + link_mid_2_part + link_mid_3_part

# %%
response = requests.get(link, timeout = 15)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
job_links = []
def get_links(soup, job_links):
    all_links = soup.find_all('div', class_ = 'Box-sc-7ekkso-0 Position-b2pct5-0 Position__Relative-b2pct5-1 VacancySerpItem__ShadowBox-p4qu0m-0 hthPRS')
    for job_add in all_links:
        job_links.append(link_first_part+job_add.find('a', {'class':'x--job-link t--job-link SearchVacancyResultsComponent__StyledVacancySerpItem-n25jij-0 dQDQbr'}).get('href'))

# %%
max_pages = soup.find('div', class_ = 'Div-v2w9ke-0 Flex-sc-4aokm-0 eykbax').text.split()[2]

# %%
for page in tqdm(range(1, int(max_pages)+1)[:]):
    url = link_first_part +link_mid_1_part + str(page) + link_mid_2_part + link_mid_3_part
    response = requests.get(url, timeout = 15)
    soup = BeautifulSoup(response.content, 'html.parser')
    get_links(soup, job_links)
    sleep(0.6)
# Out:
# HBox(children=(IntProgress(value=0, max=23), HTML(value='')))

# %%
def get_content(soup):
    try:
        content = soup.find('div', class_ = 'Div-v2w9ke-0 fjQgMg').get_text()
    except:
        content = np.nan
    try:    
        title = soup.find('div', {'class' : 'Div-v2w9ke-0 hPuVjT'}).find('h1').get('title')
    except:
        title = np.nan
    try:
        company = soup.find('div', class_ = 'Div-v2w9ke-0 cvwY').find('a').get('title')
    except:
        company = np.nan
    try:
        published = soup.find('span', class_ = 'Span-bhy2uh-0 Badge-ndaeev-0 krRxxu').get_text()
    except: 
        published = np.nan
    try:
        location = soup.find('span', class_ = 'Span-bhy2uh-0 Text__span-sc-1vcmz87-8 YbklG Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 gdfMMD').get_text()
    except: 
        location = np.nan
        
    return content, title, company, published, location

# %%
get_content(soup)
# Out:
# (nan,
#  'Senior Data Analyst Product Owner Finance (h/f) - 100% 100%',
#  nan,
#  '20.09.2019',
#  nan)

# %%
cols = ['date', 'company', 'title', 'published', 'content', 'location']
df_datascientist = pd.DataFrame(columns = cols)
df_datascientist
# Out:
# Empty DataFrame
# Columns: [date, company, title, published, content, location]
# Index: []

# %%
for job in tqdm(job_links[:]):
    response = requests.get(job, timeout = 15)
    soup = BeautifulSoup(response.content, 'html.parser')
    content, title, company, published, location = get_content(soup)
    
    df = df.append({
        'date': datetime.now(), 
        'company': company, 
        'title': title, 
        'published': published, 
        'content': content,
        'location': location
        
        
    }, ignore_index = True)
    sleep(0.6)

# %%
df_datascientist['location'] = df['location'].str.replace('—', '')
df_datascientist

# %% [markdown]
# ### Data Analyst

# %%
# Create the link (it is a better idea to constuct the especially link if you notice a specific pattern..)
link_first_part = 'https://www.jobs.ch'
link_mid_1_part = '/en/vacancies/?page='
link_mid_2_part = '&term='
link_mid_3_part = "Data%20Analyst"

link = link_first_part + link_mid_1_part + link_mid_2_part + link_mid_3_part

response = requests.get(link, timeout = 15)
soup = BeautifulSoup(response.content, 'html.parser')

job_links = []
def get_links(soup, job_links):
    all_links = soup.find_all('div', class_ = 'Box-sc-7ekkso-0 Position-b2pct5-0 Position__Relative-b2pct5-1 VacancySerpItem__ShadowBox-p4qu0m-0 hthPRS')
    for job_add in all_links:
        job_links.append(link_first_part+job_add.find('a', {'class':'x--job-link t--job-link SearchVacancyResultsComponent__StyledVacancySerpItem-n25jij-0 dQDQbr'}).get('href'))



max_pages = soup.find('div', class_ = 'Div-v2w9ke-0 Flex-sc-4aokm-0 eykbax').text.split()[2]

for page in tqdm(range(1, int(max_pages)+1)[:]):
    url = link_first_part +link_mid_1_part + str(page) + link_mid_2_part + link_mid_3_part
    response = requests.get(url, timeout = 15)
    soup = BeautifulSoup(response.content, 'html.parser')
    get_links(soup, job_links)
    sleep(0.6)

def get_content(soup):
    try:
        content = soup.find('div', class_ = 'Div-v2w9ke-0 fjQgMg').get_text()
    except:
        content = np.nan
    try:    
        title = soup.find('div', {'class' : 'Div-v2w9ke-0 hPuVjT'}).find('h1').get('title')
    except:
        title = np.nan
    try:
        company = soup.find('div', class_ = 'Div-v2w9ke-0 cvwY').find('a').get('title')
    except:
        company = np.nan
    try:
        published = soup.find('span', class_ = 'Span-bhy2uh-0 Badge-ndaeev-0 krRxxu').get_text()
    except: 
        published = np.nan
    try:
        location = soup.find('span', class_ = 'Span-bhy2uh-0 Text__span-sc-1vcmz87-8 YbklG Span-bhy2uh-0 Text__span-sc-1vcmz87-8 Text-sc-1vcmz87-9 gdfMMD').get_text()
    except: 
        location = np.nan
        
    return content, title, company, published, location

get_content(soup)

cols = ['date', 'company', 'title', 'published', 'content', 'location']
df_dataanalyst = pd.DataFrame(columns = cols)
df_dataanalyst

for job in tqdm(job_links[:]):
    response = requests.get(job, timeout = 15)
    soup = BeautifulSoup(response.content, 'html.parser')
    content, title, company, published, location = get_content(soup)
    
    df = df.append({
        'date': datetime.now(), 
        'company': company, 
        'title': title, 
        'published': published, 
        'content': content,
        'location': location
        
        
    }, ignore_index = True)
    sleep(0.6)


df_dataanalyst['location'] = df['location'].str.replace('—', '')
df_dataanalyst
