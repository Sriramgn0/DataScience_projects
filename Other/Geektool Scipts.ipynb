# %%
#python
#uncomment python line above if running from shell
from datetime import date
#prints the modules

if date(2019,12,4) == date.today():
    print ("Day 3 Machine Learning (Supervised): Classifiers I")

elif date(2019,12,5) == date.today():
    print ("Day 4 Machine Learning (Supervised): Classifiers II")

elif date(2019,12,6) == date.today():
    print ("Day 5 Machine Learning (Supervised): Trees")
 
elif date(2019,12,9) == date.today():
    print ("Day 6 Machine Learning (Supervised): Improving ML Models")
    
elif date(2019,12,10) == date.today():
    print ("Day 7 Machine Learning (Supervised): Learning Challenge")    

elif date(2019,12,11) == date.today():
    print ("Day 1 Machine Learning (Unsupervised): Clustering")
    
elif date(2019,12,12) == date.today():
    print ("Day 2 Machine Learning (Unsupervised):Dimensionality Reduction, Outlier Detection")

elif date(2019,12,13) == date.today():
    print ("Day 3 Machine Learning (Unsupervised): Learning Challenge")
    
elif date(2019,12,16) == date.today():
    print ("Day 1 Visualization: Introduction")
    
elif date(2019,12,17) == date.today():
    print ("Day 2 Visualization: Mapping")
    
elif date(2019,12,18) == date.today():
    print ("Day 3 Visualization: Design")
    
elif date(2019,12,19) == date.today():
    print ("Day 4 Visualization: Story Telling")
    
elif date(2019,12,20) == date.today():
    print ("Day 5 Visualization: Web Interactive")
    
elif date(2019,12,21) <= date.today() <= date(2020,1,5):
    print ("MERRY CHRISTMAS! HO ho Ho")

elif date(2020,1,6) == date.today():
    print ("Day 1 Neural Networks")
    
elif date(2020,1,7) == date.today():
    print ("Day 2 Neural Networks: Exercises")
    
elif date(2020,1,8) == date.today():
    print ("Day 3 Neural Networks: CNNs")
    
elif date(2020,1,9) == date.today():
    print ("Day 4 Neural Networks: Exercises")
    
elif date(2020,1,10) == date.today():
    print ("Day 5 Neural Networks: Advanced topics on CNNs")

elif date(2020,1,13) == date.today():
    print ("Day 1 Natural Language Processing: Introduction to NLP")

elif date(2020,1,14) == date.today():
    print ("Day 2 Natural Language Processing: Word embeddings")
    
elif date(2020,1,15) == date.today():
    print ("Day 3 Natural Language Processing: RNNs & LSTM")
    
elif date(2020,1,16) == date.today():
    print ("Day 4 Natural Language Processing: Advanced NLP topics")
    
elif date(2020,1,17) == date.today():
    print ("Day 5 Natural Language Processing: Advanced NLP topics")
    
elif date(2020,1,20) <= date.today() <= date(2020,2,7):
    print ("PROJECT PHASE")
    
elif date(2020,2,10) <= date.today() <= date(2020,2,14):
    print ("Wrapping up & Project presentations")

else:
    print("Script failed! -_- ? ")
# Out:
# Machine Learning (Supervised): Classifiers II

# %%
#python
#uncomment python line above if running from shell
from datetime import date
#prints the weeks

if date(2019,12,4) <= date.today() <= date(2019,12,8):
    print ("Week 4")

elif date(2019,12,9) <= date.today() <= date(2019,12,15):
    print ("Week 5")
    
elif date(2019,12,16) <= date.today() <= date(2019,12,20):
    print ("Week 6")

elif date(2020,1,6) <= date.today() <= date(2020,1,12):
    print ("Week 7")
    
elif date(2020,1,13) <= date.today() <= date(2020,1,19):
    print ("Week 8")
    
elif date(2020,1,20) <= date.today() <= date(2020,1,26):
    print ("Week 9")

elif date(2020,1,27) <= date.today() <= date(2020,2,2):
    print ("Week 10")
    
elif date(2020,2,3) <= date.today() <= date(2020,2,9):
    print ("Week 11")
    
elif date(2020,2,10) <= date.today() <= date(2020,2,14):
    print ("Week 12")

else:
    print("Script failed! -_- ? ")
# Out:
# Week 4
